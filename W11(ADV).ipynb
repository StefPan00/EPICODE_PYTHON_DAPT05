# %%
#W11 AdventureWorks

# %%
# %run connessioneSQL.py

# %%
query = "SELECT * FROM dimemployee"
de=pd.read_sql(query, db_engine)
de
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
query="SELECT * FROM dimemployeesalesterritory"
des=pd.read_sql(query, db_engine)
des
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
# Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey
de=de.set_index("EmployeeKey")
des=des.set_index("EmployeeKey")
print("shape di de", de.shape)
print("shape di des", des.shape)
# Out:
# shape di de (296, 27)
# shape di des (39, 1)

# %%
de_join_des=de.join(des)
de_join_des=de_join_des.reset_index()
de_join_des[["EmployeeKey","SalesTerritoryKey"]]
# Out:
#      EmployeeKey  SalesTerritoryKey
# 0              1                NaN
# 1              2                NaN
# 2              3                NaN
# 3              4                NaN
# 4              5                NaN
# ..           ...                ...
# 312          292                7.0
# 313          293                1.0
# 314          294                9.0
# 315          295                8.0
# 316          296                9.0
#
# [317 rows x 2 columns]

# %%
#Controlliamo la dimensione del DataFrame risultante: è quella attesa?
de_join_des.shape
#317=296 da emp con 21 dup da des =317 della join
# Out:
# (317, 29)

# %%
#Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa e il DataFrame risultante della join precedente, usando le colonne SalesTerritoryKey
de_join_des=de_join_des.set_index("SalesTerritoryKey")
de_join_des
# Out:
#                    EmployeeKey  ParentEmployeeKey  \
# SalesTerritoryKey
# NaN                          1               18.0
# NaN                          2                7.0
# NaN                          3               14.0
# NaN                          4                3.0
# NaN                          5                3.0
# ...                        ...                ...
# 7.0                        292              290.0
# 1.0                        293              272.0
# 9.0                        294              277.0
# 8.0                        295              290.0
# 9.0                        296              294.0
#
#                    EmployeeNationalIDAlternateKey  \
# SalesTerritoryKey
# NaN                                      14417807
# NaN                                     253022876
# NaN                                     509647174
# NaN                                     112457891
# NaN                                     112457891
# ...

# %%
query="SELECT * FROM dimsalesterritory"
dst=pd.read_sql(query, db_engine)
dst
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
dst=dst.set_index("SalesTerritoryKey")
dst
# Out:
#                    SalesTerritoryAlternateKey SalesTerritoryRegion  \
# SalesTerritoryKey
# 1                                           1            Northwest
# 2                                           2            Northeast
# 3                                           3              Central
# 4                                           4            Southwest
# 5                                           5            Southeast
# 6                                           6               Canada
# 7                                           7               France
# 8                                           8              Germany
# 9                                           9            Australia
# 10                                         10       United Kingdom
# 11                                          0         Corporate HQ
#
#                   SalesTerritoryCountry SalesTerritoryGroup  \
# SalesTerritoryKey
# 1                         United States       North America
# ...

# %%
#join
dst_join_des=dst.join(de_join_des)
dst_join_des
# Out:
#                    SalesTerritoryAlternateKey SalesTerritoryRegion  \
# SalesTerritoryKey
# 1.0                                         1            Northwest
# 1.0                                         1            Northwest
# 1.0                                         1            Northwest
# 1.0                                         1            Northwest
# 1.0                                         1            Northwest
# 2.0                                         2            Northeast
# 2.0                                         2            Northeast
# 2.0                                         2            Northeast
# 3.0                                         3              Central
# 3.0                                         3              Central
# 3.0                                         3              Central
# 3.0                                         3              Central
# 3.0                                         3              Central
# ...
